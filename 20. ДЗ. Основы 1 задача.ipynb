# %%
#Клиент покупает кофе в кафе. За каждые 6 чашек, 1 чашка даётся в качестве бонуса
#Задача: запросить у пользователя кол-во чашек на покупку, вычислить полагающееся кол-во бонусных чашек кофе и вывести это число на консоль.
print('Добро пожаловать в кафе!')

a_input = input('Сколько чашек кофе сегодня хотите купить? ')    #вводим количество чашек при компиляции программы
a = int(a_input)                                                 #переводим введенное значение в число(т.к. input всегда передает строку)

b_math = a/6                                                     #вычисляем сколько бонусных чашек у нас есть
b = int(b_math)                                                  #переводим формат float в формат int(чтобы не было запятой)

print ('Поздравляем! Вы получаете {} кофе в подарок!'.format(b)) #выводим текст с полученным значением

c = a+b                                                          #считаем общее количество чашек

print ('Итого Ваш заказ - {}'.format(c))                         #выводим общее количество чашек
# Out:
# Добро пожаловать в кафе!
# Сколько чашек кофе сегодня хотите купить? 12
# Поздравляем! Вы получаете 2 кофе в подарок!
# Итого Ваш заказ - 14
